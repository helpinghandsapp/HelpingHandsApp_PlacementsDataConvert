# %% [markdown]
# ## This notebook is for organizing and converting runresults data from Volunteer Toronto website

# %%
#uncomment if pandas is not already installed
#!pip install pandas
import pandas as pd

# %% [markdown]
# ### 1. Load csv file

# %% [markdown]
# #### Input file name

# %%
file_name = 'runresults_200929.csv'
df = pd.read_csv(file_name,engine='python')
df.head()
# Out:
#                                        position_name  \
# 0               Virtual Community Outreach Volunteer
# 1                               Youth Council Member
# 2                    Call & Response Youth Volunteer
# 3    Virtual Program Assistant Volunteer (Bilingual)
# 4  Volunteer T.E.A.R.䋢(Teens Ending Abusive Relat...
#
#                                         position_url  \
# 0  https://www.volunteertoronto.ca/networking/app...
# 1  https://www.volunteertoronto.ca/networking/app...
# 2  https://www.volunteertoronto.ca/networking/app...
# 3  https://www.volunteertoronto.ca/networking/app...
# 4  https://www.volunteertoronto.ca/networking/app...
#
#                 position_category  \
# 0  Accessibility and Disabilities
# 1                Arts and Culture
# 2   1. Suitable for Youth (14-17)
# 3   1. Suitable for Youth (14-17)
# 4                Arts and Culture
#
#                                         position_org position_date_posted  \
# 0                Citizens With Disabilities- Ontario            2020/9/25
# 1  The Corporation of Roy Thomson Hall and Massey...            2020/9/24
# 2  THE CORPORATION OF MASSEY HALL AND ROY THOMSON...            2020/9/24
# 3                   Senior Person's Living Connected            2020/9/18
# 4                            Victim Services Toronto            2020/9/16
#
#   position_city position_location position_position_type  \
# 0       Toronto           Ontario    Volunteer from Home
# 1       Toronto           Ontario    Volunteer from Home
# 2       Toronto           Ontario                    NaN
# 3       Toronto               NaN    Volunteer from Home
# 4       Toronto           Ontario                    NaN
#
#                                 position_description  \
# 0  CWDO needs your energy and your passion!\rCWDO...
# 1  Calling all youth with a passion for music! Th...
# 2  Calling all Toronto-area secondary school stud...
# 3  About Us\rSenior Persons Living Connected (SPL...
# 4  Volunteer T.E.A.R.䋢(Teens Ending Abusive Relat...
#
#                                     position_contact
# 0                                                NaN
# 1                                                NaN
# 2  Visit our website for more information\rAny Qu...
# 3  To learn more about our organization, please v...
# 4  Apply: Email your resume to tearyouth@victimse...

# %% [markdown]
# ### 2. Select and rename columns for target file

# %%
column_names=[]

#job title
if 'position_name' in df:
    df.rename(columns = {'position_name':'job_title'}, inplace=True)
elif 'positions_name' in df:
    df.rename(columns = {'positions_name':'job_title'}, inplace=True)

column_names.append('job_title')

#description
if 'position_description' in df:
    df.rename(columns = {'position_description':'description'}, inplace=True)
elif 'position_details_description' in df:
    df.rename(columns = {'position_details_description':'description'}, inplace=True)
elif 'positions_details' in df:
    df.rename(columns = {'positions_details':'description'}, inplace=True)
elif 'positions_description' in df:
    df.rename(columns = {'positions_description':'description'}, inplace=True)
if 'description' in df:
    column_names.append('description')

#application_process
if 'position_contact' in df:
    df.rename(columns = {'position_contact':'application_process'}, inplace=True)
elif 'position_details_contact' in df:
    df.rename(columns = {'position_details_contact':'application_process'}, inplace=True)
elif 'positions_contact' in df:
    df.rename(columns = {'positions_contact':'application_process'}, inplace=True)
if 'application_process' in df:
    column_names.append('application_process')

#placement_miscellaneous
column_names.append('placement_miscellaneous')

#position_url
if 'positions_url' in df:
    df.rename(columns = {'positions_url':'position_url'}, inplace=True)
elif 'position_details_url' in df:
    df.rename(columns = {'position_details_url':'position_url'}, inplace=True)
if 'position_url' in df:
    column_names.append('position_url')

#####################################################################################
#position_category
if 'placement_interests' in df:
    df.rename(columns = {'placement_interests':'position_category'}, inplace=True)
elif 'positions_category' in df:
    df.rename(columns = {'positions_category':'position_category'}, inplace=True)
elif 'position_interests' in df:
    df.rename(columns = {'position_interests':'position_category'}, inplace=True)
elif 'position_areas_of_interest' in df:
    df.rename(columns = {'position_areas_of_interest':'position_category'}, inplace=True)
if 'position_category' in df:
    column_names.append('position_category')    
    
#name
if 'position_org' in df:
    df.rename(columns = {'position_org':'name'}, inplace=True)
elif 'position_details_org' in df:
    df.rename(columns = {'position_details_org':'name'}, inplace=True)
elif 'positions_org' in df:
    df.rename(columns = {'positions_org':'name'}, inplace=True)
elif 'positions_organization' in df:
    df.rename(columns = {'positions_organization':'name'}, inplace=True)
elif 'position_organization' in df:
    df.rename(columns = {'position_organization':'name'}, inplace=True)
elif 'position_org_name' in df:
    df.rename(columns = {'position_org_name':'name'}, inplace=True)
if 'name' in df:
    column_names.append('name')
    
#position_dateposted
if 'position_date_posted' in df:
    df.rename(columns = {'position_date_posted':'position_dateposted'}, inplace=True)
elif 'positions_dateposted' in df:
    df.rename(columns = {'positions_dateposted':'position_dateposted'}, inplace=True)
elif 'position_details_date_posted' in df:
    df.rename(columns = {'position_details_date_posted':'position_dateposted'}, inplace=True)
elif 'placement_date_posted' in df:
    df.rename(columns = {'placement_date_posted':'position_dateposted'}, inplace=True)
if 'position_dateposted' in df:
    column_names.append('position_dateposted')
    
#position_deadline
if 'placement_deadline' in df:
    df.rename(columns = {'placement_deadline':'placement_deadline'}, inplace=True)

if 'position_deadline' in df:
    column_names.append('position_deadline')

#city
if 'position_city' in df:
    df.rename(columns = {'position_city':'city'}, inplace=True)
elif 'placement_city' in df:
    df.rename(columns = {'placement_city':'city'}, inplace=True)
if 'city' in df:
    column_names.append('city')
    if 'position_location' in df:
        df.rename(columns = {'position_location':'province'}, inplace=True)
        column_names.append('province')

#email
if 'positions_contact_email' in df:
    df.rename(columns = {'positions_contact_email':'email'}, inplace=True)
elif 'position_email' in df:
    df.rename(columns = {'position_email':'email'}, inplace=True)
if 'email' in df:
    column_names.append('email')

#address
if 'positions_address' in df:
    df.rename(columns = {'positions_address':'address'}, inplace=True)
elif 'position_address' in df:
    df.rename(columns = {'position_address':'address'}, inplace=True)
if 'address' in df:
    column_names.append('address')
    
if 'postal_code' in df:
    column_names.append('postal_code')
if 'created_at' in df:
    column_names.append('created_at')
if 'updated_at' in df:
    column_names.append('updated_at')
if 'expiration_date' in df:
    #default: "2100-07-20"
    column_names.append('expiration_date')
if 'organization_id' in df:
    column_names.append('organization_id')
if 'position_phone' in df:
    column_names.append('position_phone')

column_names
# Out:
# ['job_title',
#  'description',
#  'application_process',
#  'placement_miscellaneous',
#  'position_url',
#  'position_category',
#  'name',
#  'position_dateposted',
#  'city',
#  'province']

# %% [markdown]
# ### 3. Create new dataframe with modified column names
# ###       Add website and skills&categories column

# %%
df['placement_miscellaneous']=df['description']
df_placements = df[column_names]
df_placements['position_postedon']= 'Volunteer Toronto'

import numpy as np
# add skills and categories column
for i in range (12):
    if i<6:
        index = '{} {}'.format('skills', i+1)
        df_placements[index] = np.nan
    else:
        index = '{} {}'.format('categories', i-5)
        df_placements[index] = np.nan
df_placements.head()

# skills and categories update column name
df_placements.rename(columns = {'skills 1':'skills','skills 2':'skills','skills 3':'skills',
                                'skills 4':'skills','skills 5':'skills','skills 6':'skills',
                                'categories 1':'categories','categories 2':'categories',
                               'categories 3':'categories','categories 4':'categories',
                               'categories 5':'categories','categories 6':'categories'}, inplace=True)
df_placements.head()
# Out:
#                                            job_title  \
# 0               Virtual Community Outreach Volunteer
# 1                               Youth Council Member
# 2                    Call & Response Youth Volunteer
# 3    Virtual Program Assistant Volunteer (Bilingual)
# 4  Volunteer T.E.A.R.䋢(Teens Ending Abusive Relat...
#
#                                          description  \
# 0  CWDO needs your energy and your passion!\rCWDO...
# 1  Calling all youth with a passion for music! Th...
# 2  Calling all Toronto-area secondary school stud...
# 3  About Us\rSenior Persons Living Connected (SPL...
# 4  Volunteer T.E.A.R.䋢(Teens Ending Abusive Relat...
#
#                                  application_process  \
# 0                                                NaN
# 1                                                NaN
# 2  Visit our website for more information\rAny Qu...
# 3  To learn more about our organization, please v...
# 4  Apply: Email your resume to tearyouth@victimse...
#
#                              placement_miscellaneous  \
# 0  CWDO needs your energy and your passion!\rCWDO...
# 1  Calling all youth with a passion for music! Th...
# 2  Calling all Toronto-area secondary school stud...
# 3  About Us\rSenior Persons Living Connected (SPL...
# 4  Volunteer T.E.A.R.䋢(Teens Ending Abusive Relat...
#
#                                         position_url  \
# 0  https://www.volunteertoronto.ca/networking/app...
# 1  https://www.volunteertoronto.ca/networking/app...
# 2  https://www.volunteertoronto.ca/networking/app...
# 3  https://www.volunteertoronto.ca/networking/app...
# 4  https://www.volunteertoronto.ca/networking/app...
#
#                 position_category  \
# 0  Accessibility and Disabilities
# 1                Arts and Culture
# 2   1. Suitable for Youth (14-17)
# 3   1. Suitable for Youth (14-17)
# 4                Arts and Culture
#
#                                                 name position_dateposted  \
# 0                Citizens With Disabilities- Ontario           2020/9/25
# 1  The Corporation of Roy Thomson Hall and Massey...           2020/9/24
# 2  THE CORPORATION OF MASSEY HALL AND ROY THOMSON...           2020/9/24
# 3                   Senior Person's Living Connected           2020/9/18
# 4                            Victim Services Toronto           2020/9/16
#
#       city province  ...  skills  skills  skills  skills  categories  \
# 0  Toronto  Ontario  ...     NaN     NaN     NaN     NaN         NaN
# 1  Toronto  Ontario  ...     NaN     NaN     NaN     NaN         NaN
# 2  Toronto  Ontario  ...     NaN     NaN     NaN     NaN         NaN
# 3  Toronto      NaN  ...     NaN     NaN     NaN     NaN         NaN
# 4  Toronto  Ontario  ...     NaN     NaN     NaN     NaN         NaN
#
#    categories  categories  categories  categories  categories
# 0         NaN         NaN         NaN         NaN         NaN
# 1         NaN         NaN         NaN         NaN         NaN
# 2         NaN         NaN         NaN         NaN         NaN
# 3         NaN         NaN         NaN         NaN         NaN
# 4         NaN         NaN         NaN         NaN         NaN
#
# [5 rows x 23 columns]

# %% [markdown]
# ### 4. Export dataframe as a csv file

# %%
output_file_name = 'placement_200929.csv'

# Export to current file:
df_placements.to_csv(output_file_name, index=False, escapechar="\r")

# Or to export to a target file, update the path:
# import os
# path ='Placements'
# output_file = os.path.join(path, output_file_name)
# df_placements.to_csv(output_file, index=False)
